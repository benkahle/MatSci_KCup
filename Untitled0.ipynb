# %%
import matplotlib.pyplot as pp
import pandas
import math
import sys
import numpy as np
import scipy.optimize

# %%
print sys.argv[1]
# Out:
# -f

# %%
casingSR = pandas.read_table("casing_slowRamp.csv", sep=',', names=['Time', 'Temp', 'Weight'])
filterSR = pandas.read_table("plastic_filter_slowRamp.csv", sep=',', names=['Time', 'Temp', 'Weight'])

# %%
#pp.plot(casingSR['Time'],casingSR['Weight'])
pp.plot(filterSR['Time'],filterSR['Weight'])

# %%
casingMaxWeight = 5.823
filterMaxWeight = 13.97

# %%
filterSR['Weight'] = filterSR['Weight']/filterMaxWeight
casingSR['Weight'] = casingSR['Weight']/casingMaxWeight

# %%
pp.plot(casingSR['Time'],casingSR['Weight'])
pp.plot(filterSR['Time'],filterSR['Weight'])
pp.legend(['Casing', 'Filter'], 'lower left')

# %%
trend = np.polyfit(dataframe['Time'],dataframe['Weight'],2)

# %%
pp.plot(trend)

# %%
trendFunc = np.poly1d(trend)

# %%
pp.plot(dataframe['Time'],trendFunc(dataframe['Time']),'r-')
pp.plot(dataframe['Time'],dataframe['Weight'])
